# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
from IPython.display import JSON

# %%
# get Citybikes network data
city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()

# view json
city_bike_networks
# Out:
# {'networks': [{'id': 'abu-dhabi-careem-bike',
#    'name': 'Abu Dhabi Careem BIKE',
#    'location': {'latitude': 24.4866,
#     'longitude': 54.3728,
#     'city': 'Abu Dhabi',
#     'country': 'AE'},
#    'href': '/v2/networks/abu-dhabi-careem-bike',
#    'company': ['Careem'],
#    'gbfs_href': 'https://dubai.publicbikesystem.net/customer/gbfs/v2/en/gbfs.json'},
#   {'id': 'acces-velo-saguenay',
#    'name': 'Accès Vélo',
#    'location': {'latitude': 48.433333,
#     'longitude': -71.083333,
#     'city': 'Saguenay',
#     'country': 'CA'},
#    'href': '/v2/networks/acces-velo-saguenay',
#    'company': ['PBSC Urban Solutions'],
#    'gbfs_href': 'https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json'},
#   {'id': 'aksu',
#    'name': 'Aksu',
#    'location': {'latitude': 41.1664,
#     'longitude': 80.2617,
#     'city': '阿克苏市 (Aksu City)',
#     'country': 'CN'},
#    'href': '/v2/networks/aksu',
#    'company': ['阿克苏公共服务']},
#   {'id': 'alba',
#    'name': 'Alba',
# ...

# %%
# get information about bike network in Bentonville, Arkansas

network_id = 'bentonville'
network_json = requests.get("http://api.citybik.es/v2/networks/" + network_id).json()
network_json
# Out:
# {'network': {'id': 'bentonville',
#   'name': 'Bentonville BCycle',
#   'location': {'latitude': 36.3605,
#    'longitude': -94.1996,
#    'city': 'Bentonville, AR',
#    'country': 'US'},
#   'href': '/v2/networks/bentonville',
#   'company': ['BCycle, LLC'],
#   'system': 'BCycle',
#   'gbfs_href': 'https://gbfs.bcycle.com/bcycle_bentonville/gbfs.json',
#   'stations': [{'id': '01dd6bf9fa7543bc298e1234857cafd2',
#     'name': 'Walmart International',
#     'latitude': 36.36721,
#     'longitude': -94.2196,
#     'timestamp': '2025-07-08T19:41:35.532658+00:00Z',
#     'free_bikes': 7,
#     'empty_slots': 6,
#     'extra': {'uid': 'bcycle_bentonville_7644',
#      'renting': 1,
#      'returning': 1,
#      'last_updated': 1752003695,
#      'address': '701 S Walton Blvd',
#      'rental_uris': {'android': 'https://www.bcycle.com/applink?system_id=bcycle_bentonville&station_id=bcycle_bentonville_7644&platform=android',
# ...

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
import json

with open('bentonville.json', 'w') as f:
  json.dump(network_json, f)

# %%
pd.json_normalize(network_json['network']['stations'])
# Out:
#                                   id  \
# 0   01dd6bf9fa7543bc298e1234857cafd2
# 1   1f41000125233b542b7f1e9b00f2279a
# 2   26267de8a8967d4990dc91f5c2273d47
# 3   4287eaf68bca4baa215d17d441972082
# 4   5c10fbb3ae0380143bbd37f87e83a99e
# 5   750f5defcdd385472acea5a478c28a58
# 6   7da09e44a3907e682e00fb00237f6b9a
# 7   84a1127497677230c2ea4f1bab94dea6
# 8   876df7a503f980f4a4a93bbf53b88ac1
# 9   8a07761a196c92b8e35ac5b38000b546
# 10  9adbd0ffb7bb2ffc2d40de0679ac9b8a
# 11  9c28ed35bb978e0b808068b7bdd8bde4
# 12  9cdbeb4606da630d5748853980afa2de
# 13  a033345f645e937fb34a3a65b52d43dc
# 14  a0e9ee5fca5f3b8264d3e70717e243b8
# 15  a20fe365051d4b3e1f337da916223c99
# 16  a350a706643b5d089b9872904c397829
# 17  a750658df42226ea328c36cf7038475f
# 18  b556cf1b2cee180caf2a93c55737d96f
# 19  b6e131b74f42ab0ce8bc50bb86008c03
# 20  bfd26ffd2c0b53d7cf4a4d1066f73eb1
# 21  dc3fdaf8000a819974efc0208924ceab
# 22  eeb539bac3b5fb931948cbcdbbee7f18
# 23  f696c18dc501ce34085b0f694e7342da
#
# ...

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
names = [station['name'] for station in network_json['network']['stations']]
longitude = [station['longitude'] for station in network_json['network']['stations']]
latitude = [station['latitude'] for station in network_json['network']['stations']]
free_bikes = [station['free_bikes'] for station in network_json['network']['stations']]
empty_slots = [station['empty_slots'] for station in network_json['network']['stations']]

# %%
import pandas as pd
df_bentonville = pd.DataFrame({'name' : names,
                          'longitude' : longitude,
                          'latitude' : latitude
                          ,'free_bikes' : free_bikes,
                          'empty_slots' : empty_slots})

# %%
print(df_bentonville)
# Out:
#                                                  name  longitude  latitude  \
# 0                               Walmart International  -94.21960  36.36721
# 1                                Walmart Supply Chain  -94.22290  36.37710
# 2                                     Walmart Ol' Roy  -94.18853  36.36551
# 3                              Walmart Welcome Center  -94.19446  36.36442
# 4          Walmart Training / Redbird Office Building  -94.19562  36.34648
# 5                                     Walmart Purpose  -94.19119  36.36433
# 6   Walton Family Whole Health and Fitness Center ...  -94.19308  36.36562
# 7                                 Walmart 8th & Plate  -94.19128  36.36276
# 8                                    Walmart J Street  -94.20084  36.34559
# 9                        Walmart Global People Center  -94.21428  36.36455
# 10                             Sam's Club Home Office  -94.18702  36.34588
# ...

# %%
# this made it easier to copy/paste the latitude and longitude value
# I will not do it this way in the future and I would have saved the data into a csv before parsing

df_bentonville.to_csv('bentonville.csv')

# %%
# load the data into a pandas DataFrame that looks better

df_bentonville= pd.json_normalize(network_json['network']['stations'])

# %%
len(df_bentonville)
# Out:
# 24

# %%
df_bentonville
# Out:
#                                                  name  longitude  latitude  \
# 0                               Walmart International  -94.21960  36.36721
# 1                                Walmart Supply Chain  -94.22290  36.37710
# 2                                     Walmart Ol' Roy  -94.18853  36.36551
# 3                              Walmart Welcome Center  -94.19446  36.36442
# 4          Walmart Training / Redbird Office Building  -94.19562  36.34648
# 5                                     Walmart Purpose  -94.19119  36.36433
# 6   Walton Family Whole Health and Fitness Center ...  -94.19308  36.36562
# 7                                 Walmart 8th & Plate  -94.19128  36.36276
# 8                                    Walmart J Street  -94.20084  36.34559
# 9                        Walmart Global People Center  -94.21428  36.36455
# 10                             Sam's Club Home Office  -94.18702  36.34588
# ...
